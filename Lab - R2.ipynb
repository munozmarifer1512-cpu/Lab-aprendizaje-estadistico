# %% [markdown]
# # Laboratorio de regresión - 2

# %% [markdown]
# |                |   |
# :----------------|---|
# | **Nombre**     |María Fernanda Muñoz Sevilla   |
# | **Fecha**                        31/08/2025|   |
# | **Expediente**                      751190 |   |

# %% [markdown]
# ## Regresión polinomial

# %% [markdown]
# Observa la siguiente gráfica.

# %%
import matplotlib.pyplot as plt; import numpy as np
# %matplotlib inline
np.random.seed(0)
x = np.linspace(-3, 3, 100); y = 1 + 4*x**2 + np.random.normal(0, 1, 100)

plt.show(); plt.xlabel("x"); plt.ylabel("y")
plt.scatter(x, y); plt.grid()

# %% [markdown]
# Utiliza `sklearn` para realizar una regresión lineal simple ($\hat{y} = \hat{\beta_0} + \hat{\beta_1}x $)

# %%
from sklearn.linear_model import LinearRegression
x1=x.reshape([-1,1])
lr=LinearRegression()
lr.fit(x1,y)
beta0 = lr.intercept_
print("Beta 0: ",beta0)
# Out:
# Beta 0:  13.30223225795873

# %%
beta1=lr.coef_
print("Beta 1: ",beta1)
# Out:
# Beta 1:  [-0.04955448]

# %% [markdown]
# Crea una gráfica donde se muestren las observaciones como una nube de puntos y la línea que ajustaste con regresión. Calcula el métrico $R^2$.

# %%
plt.scatter(x,y)
plt.plot(x,lr.predict(x1))
plt.show()

# %%
from sklearn.metrics import r2_score
r2= r2_score(y,lr.predict(x1))
print("R^2: ",r2)
# Out:
# R^2:  5.80345273922811e-05

# %% [markdown]
# Podemos ver que el ajuste no es correcto, pues parece que tiene un comportamiento cuadrático y estamos intentando ajustar una línea recta.
#
# En lugar de hacer una regresión lineal simple, quizás podamos extender el modelo para que tenga varios factores dentro:
#
# $$ Y = \beta_0 + \beta_1 X + \beta_2 X^2 + ... + \beta_p X^p + \epsilon$$

# %% [markdown]
# Ajusta un modelo cuadrático con `sklearn` ($\hat{y} = \hat{\beta_0} + \hat{\beta_1}x + \hat{\beta_1}x^2 $) y calcula su $R^2$.

# %%
x2=x1**2
X=np.hstack([x1,x2])
lr=LinearRegression()
lr.fit(X,y)
beta0_2=lr.intercept_
print("Beta 0: ",beta0_2)
# Out:
# Beta 0:  0.619420963180481

# %%
beta1_2=lr.coef_
print("Beta 1: ",beta1_2)
# Out:
# Beta 1:  [-0.04955448  4.14388884]

# %%
r2_2=r2_score(y,lr.predict(X))
print("R^2: ",r2_2)
# Out:
# R^2:  0.9934118040713642

# %% [markdown]
# Crea una gráfica con las observaciones y la nueva curva que ajustaste.

# %%
plt.scatter(x,y)
plt.plot(x1,lr.predict(X))
plt.show()

# %% [markdown]
# Ajusta modelos de grados 3, 5, 7, 9, y 11. Calcula su $R^2$.

# %%
#Grado 3
x3=x1**3
X3=np.hstack([x1,x2,x3])
lr=LinearRegression()
lr.fit(X3,y)
beta0_3=lr.intercept_
print("Beta 0: ",beta0_3)
beta1_3=lr.coef_
print("Beta 1: ",beta1_3)
r2_3=r2_score(y,lr.predict(X3))
print("R^2: ",r2_3)
# Out:
# Beta 0:  0.6194209631804846
# Beta 1:  [-6.55753967e-02  4.14388884e+00  2.90847549e-03]
# R^2:  0.9934129585186598

# %%
#Grado 5
x4=x1**4
x5=x1**5
X5=np.hstack([x1,x2,x3,x4,x5])
lr=LinearRegression()
lr.fit(X5,y)
beta0_5=lr.intercept_
print("Beta 0: ",beta0_5)
beta1_5=lr.coef_
print("Beta 1: ",beta1_5)
r2_5=r2_score(y,lr.predict(X5))
print("R^2: ",r2_5)
# Out:
# Beta 0:  0.6337116478282621
# Beta 1:  [-2.76393644e-01  4.12831746e+00  1.10135698e-01  1.97920171e-03
#  -1.05167018e-02]
# R^2:  0.9934954953676421

# %%
#Grado 7
x6=x1**6
x7=x1**7
X7=np.hstack([x1,x2,x3,x4,x5,x6,x7])
lr=LinearRegression()
lr.fit(X7,y)
beta0_7=lr.intercept_
print("Beta 0: ",beta0_7)
beta1_7=lr.coef_
print("Beta 1: ",beta1_7)
r2_7=r2_score(y,lr.predict(X7))
print("R^2: ",r2_7)
# Out:
# Beta 0:  0.6101810919961537
# Beta 1:  [-1.75155617e-01  4.18219958e+00  1.07431886e-02 -1.56446593e-02
#   1.33331414e-02  1.40889740e-03 -1.61012799e-03]
# R^2:  0.9935089341876935

# %%
#Grado 9
x8=x1**8
x9=x1**9
X9=np.hstack([x1,x2,x3,x4,x5,x6,x7,x8,x9])
lr=LinearRegression()
lr.fit(X9,y)
beta0_9=lr.intercept_
print("Beta 0: ",beta0_9)
beta1_9=lr.coef_
print("Beta 1: ",beta1_9)
r2_9=r2_score(y,lr.predict(X9))
print("R^2: ",r2_9)
# Out:
# Beta 0:  0.58901859964962
# Beta 1:  [-1.10778098e-01  4.26535653e+00 -9.23732104e-02 -6.55597796e-02
#   5.72464222e-02  1.08500851e-02 -8.45937252e-03 -5.51840642e-04
#   3.53081565e-04]
# R^2:  0.9935141799662259

# %%
#Grado 11
x10=x1**10
x11=x1**11
X11=np.hstack([x1,x2,x3,x4,x5,x6,x7,x8,x9,x10,x11])
lr=LinearRegression()
lr.fit(X11,y)
beta0_11=lr.intercept_
print("Beta 0: ",beta0_11)
beta1_11=lr.coef_
print("Beta 1: ",beta1_11)
r2_11=r2_score(y,lr.predict(X11))
print("R^2: ",r2_11)
# Out:
# Beta 0:  0.567083964495712
# Beta 1:  [ 9.00703987e-02  4.39720527e+00 -5.68294874e-01 -1.90428125e-01
#   3.69496567e-01  5.17798355e-02 -9.13700221e-02 -5.98142327e-03
#   9.92036867e-03  2.50411792e-04 -3.99285153e-04]
# R^2:  0.9935338704150221

# %% [markdown]
# Crea una gráfica por cada modelo con las observaciones y su curva.

# %%
#Grado 3
plt.scatter(x,y,color="orange")
plt.plot(x1,lr.predict(X3),color="blue")
plt.show()

# %%
#Grado 5
plt.scatter(x,y,color="orange")
plt.plot(x1,lr.predict(X5),color="blue")
plt.show()

# %%
#Grado 7
plt.scatter(x,y,color="orange")
plt.plot(x1,lr.predict(X7),color="blue")
plt.show()

# %%
#Grado 9
plt.scatter(x,y,color="orange")
plt.plot(x1,lr.predict(X9),color="blue")
plt.show()

# %%
#Grado 11
plt.scatter(x,y,color="orange")
plt.plot(x1,lr.predict(X11),color="blue")
plt.show()

# %% [markdown]
# **¿Cuál modelo consideras que es mejor? ¿Por qué?**

# %% [markdown]
# Yo creo que el mejor modelo es el 2, porque es donde el R^2 se ajusta a la parábola de los datos, sin ser demasiado complejo como los son el resto de modelos, los cuales tienen un r^2 bastante alto y están sobreajustando los datos que son ruido, mientras que el modelo 2 mantiene un equilibrio en el ajuste de r^2 y el ruido de datos.

# %% [markdown]
# Recuerda que una de las metas de ajustar modelos es para poder interpolar y extrapolar. Los datos que tenemos mantienen $x \in [-3, 3]$. ¿Qué pasaría si quisiéramos saber el valor de $y$ cuando $x=5$?
#
# Calcula la predicción $\hat{y}$ para todos los modelos creados (grados 2, 3, 5, 7, 9, y 11).

# %%
#Grado 2
xnueva=np.array([5])
xn=xnueva.reshape([-1,1])
x2_n=xn**2
X2_n=np.hstack([xn,x2_n])
y2_pred=lr.predict(X2_n)
print("Predicción de y para grado 2: ",y2_pred)
# Out:
# Predicción de y para grado 2:  [103.96886955]

# %%
x3_n=xn**3
X3_n=np.hstack([xn,x2_n,x3_n])
y3_pred=lr.predict(X3_n)
print("Predicción de y para grado 3: ",y3_pred)
# Out:
# Predicción de y para grado 3:  [104.25232439]

# %%
#Grado 5
x4_n=xn**4
x5_n=xn**5
X5_n=np.hstack([xn,x2_n,x3_n,x4_n,x5_n])
y5_pred=lr.predict(X5_n)
print("Predicción de y para grado 5: ",y5_pred)
# Out:
# Predicción de y para grado 5:  [84.59895013]

# %%
#Grado 7
x6_n=xn**6
x7_n=xn**7
X7_n=np.hstack([xn,x2_n,x3_n,x4_n,x5_n,x6_n,x7_n])
y7_pred=lr.predict(X7_n)
print("Predicción de y para grado 7: ",y7_pred)
# Out:
# Predicción de y para grado 7:  [33.74321848]

# %%
#Grado 9
x8_n=xn**8
x9_n=xn**9
X9_n=np.hstack([xn,x2_n,x3_n,x4_n,x5_n,x6_n,x7_n,x8_n,x9_n])
y9_pred=lr.predict(X9_n)
print("Predicción de y para grado 9: ",y9_pred)
# Out:
# Predicción de y para grado 9:  [215.73637926]

# %%
#Grado 11
x10_n=xn**10
x11_n=xn**11
X11_n=np.hstack([xn,x2_n,x3_n,x4_n,x5_n,x6_n,x7_n,x8_n,x9_n,x10_n,x11_n])
y11_pred=lr.predict(X11_n)
print("Predicción de y para grado 11: ",y11_pred)
# Out:
# Predicción de y para grado 11:  [-5265.34425348]

# %% [markdown]
# ¿Cuál modelo crees que sea mejor?

# %% [markdown]
# Yo creo que el mejor modelo es el 2, porque es mucho más simple, además de que no hace un sobreajuste sobre el ruido como lo son los grados 5,7,9,11. Los cuales nos dan valores muy alejados del 2 y 3, que son los más estables.

# %% [markdown]
# ## Referencia
#
# James, G., Witten, D., Hastie, T., Tibshirani, R.,, Taylor, J. (2023). An Introduction to Statistical Learning with Applications in Python. Cham: Springer. ISBN: 978-3-031-38746-3
